# %%
import matplotlib.pyplot as plt
import numpy as np
import results.metrics as mt
from src.models.coefficients import f_1, compute_f_exact, u_exact
from config.parameters import Params




params = Params(
    r = .5,
    R = np.sqrt(2),
    kappa = .1,
    vs = .5,
    a = .2,
    sig_x = .5,
    sig_y = .2,
    X_min = -2.0,
    X_max = 2.0,
    Y_min = -2.0,
    Y_max = 2.0
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 3
#       1 import matplotlib.pyplot as plt
#       2 import numpy as np
# ----> 3 import results.metrics as mt
#       4 from src.models.coefficients import f_1, compute_f_exact, u_exact
#       5 from config.parameters import Params
#
# ModuleNotFoundError: No module named 'results'

# %% [markdown]
# # Notebook des résultats:
# ## 1. Différences finies :

# %%
N_list = [10*2**k for k in range (5)]

errors, times = mt.convergence_fd(params, N_list, f_1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 N_list = [10*2**k for k in range (5)]
# ----> 3 errors, times = mt.convergence_fd(params, N_list, f_1)
#
# NameError: name 'mt' is not defined
